# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# %pip install pandas openpyxl

# %%
# !git clone https://github.com/Anand0583/text_classification_de.git
# Out:
# Cloning into 'text_classification_de'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 121.91 KiB | 664.00 KiB/s, done.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_excel("/content/text_classification_de/Enhanced_Synthetic_Data_1000.xlsx")

# %%
df.head(20)
# Out:
#                                                Text Scope
# 0             How to open a New Workbook in VS Code   Out
# 1                   Analyze a New Workbook in Excel   Out
# 2                     Format a New Workbook in Word    In
# 3                    Share a New Workbook on GitHub    In
# 4          Organize a New Workbook in Google Sheets   Out
# 5                     Format a Python script in SQL    In
# 6             Format a Python script in Google Docs    In
# 7                   Analyze a CSV file using Python   Out
# 8   How to delete a PowerPoint slide in Google Docs    In
# 9                       Edit a PDF file on OneDrive    In
# 10           Spell check for a presentation in Word   Out
# 11              How to delete a presentation in SQL   Out
# 12                    Analyze a CSV file in VS Code   Out
# 13              Analyze a Python script on OneDrive    In
# 14         How to open a Python script using Python   Out
# ...

# %%
# %cd /content/text_classification_de
# Out:
# /content/text_classification_de

# %%
from text_preprocessing import remove_tags,preprocess_text,label_encoder_fit_and_transform, generate_train_test_val_data,preprocess_function,get_encoded_train_validation_tf_data

# %%
#use preprocess.py
#df['text].apply(preprcoess)

X = df['Text']
y = df['Scope']

# %%
df.isna().sum()
# Out:
# Text     0
# Scope    0
# dtype: int64

# %%
# Assuming 'text_column' is the name of the column with the text data
df['cleaned_text'] = df['Text'].apply(lambda x: remove_tags(x))
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: preprocess_text(x))

print(df['cleaned_text'].head(10))  # Check preprocessed text
# Out:
# 0              How to open New Workbook in VS Code
# 1                    Analyze New Workbook in Excel
# 2                      Format New Workbook in Word
# 3                     Share New Workbook on GitHub
# 4           Organize New Workbook in Google Sheets
# 5                      Format Python script in SQL
# 6              Format Python script in Google Docs
# 7                    Analyze CSV file using Python
# 8    How to delete PowerPoint slide in Google Docs
# 9                        Edit PDF file on OneDrive
# Name: cleaned_text, dtype: object

# %%
df = label_encoder_fit_and_transform(df,'Scope')
df.head(5)
# Out:
# Index(['Scope'], dtype='object')
#                                        Text  \
# 0     How to open a New Workbook in VS Code
# 1           Analyze a New Workbook in Excel
# 2             Format a New Workbook in Word
# 3            Share a New Workbook on GitHub
# 4  Organize a New Workbook in Google Sheets
#
#                              cleaned_text  Scope
# 0     How to open New Workbook in VS Code      1
# 1           Analyze New Workbook in Excel      1
# 2             Format New Workbook in Word      0
# 3            Share New Workbook on GitHub      0
# 4  Organize New Workbook in Google Sheets      1

# %%
generate_train_test_val_data("/content/text_classification_de/Enhanced_Synthetic_Data_1000.xlsx")
# Out:
# (1000, 2)
# The column headers :
# ['Text', 'Scope']
# (1000, 2)
# The column headers :
# ['Text', 'Scope']
# Index(['Scope'], dtype='object')
# 2
# (800, 2)
# (100, 2)
# (100, 2)

# %%
vectorizer = TfidfVectorizer()
X_vectors = vectorizer.fit_transform(X)
print(X_vectors)
# Out:
#   (0, 17)	0.2476715424572127
#   (0, 37)	0.2476715424572127
#   (0, 22)	0.41563862184732064
#   (0, 19)	0.4120177313220339
#   (0, 42)	0.4120177313220339
#   (0, 18)	0.17693325984019442
#   (0, 39)	0.40849697052573164
#   (0, 3)	0.40849697052573164
#   (1, 19)	0.5039602003550084
#   (1, 42)	0.5039602003550084
#   (1, 18)	0.21641622265240765
#   (1, 1)	0.5160625277810318
#   (1, 11)	0.42295593022133476
#   (2, 19)	0.512879212897139
#   (2, 42)	0.512879212897139
#   (2, 18)	0.22024632471760572
#   (2, 14)	0.4907920109353236
#   (2, 40)	0.429563248435513
#   (3, 19)	0.468452436314412
#   (3, 42)	0.468452436314412
#   (3, 30)	0.47118395353470155
#   (3, 20)	0.36878627264679575
#   (3, 15)	0.4506517467633681
#   (4, 19)	0.44365990595231997
#   (4, 42)	0.44365990595231997
#   :	:
#   (996, 10)	0.596784642832303
#   (996, 6)	0.5895002595554619
#   (997, 17)	0.23530537599745788
#   (997, 37)	0.23530537599745788
#   (997, 11)	0.32852658991771366
#   (997, 20)	0.30816328292736134
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vectors, y, test_size=0.3, random_state=42)

# %%
# Create a Multinomial Naive Bayes classifier
mnb = MultinomialNB()

# Train the model
mnb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on the test set
y_pred = mnb.predict(X_test)
print(X_test)
print(y_pred)
# Out:
#   (0, 27)	0.36986734408904626
#   (0, 5)	0.5067023472000055
#   (0, 12)	0.39511689362169833
#   (0, 38)	0.46319481721209915
#   (0, 10)	0.48557602988729787
#   (1, 18)	0.23812552081379967
#   (1, 14)	0.5306336138188634
#   (1, 35)	0.5841626751015686
#   (1, 6)	0.5661079166032474
#   (2, 18)	0.20357773320713335
#   (2, 30)	0.47682793598613565
#   (2, 16)	0.3853892238309268
#   (2, 27)	0.37320370502227035
#   (2, 29)	0.4647800406442758
#   (2, 8)	0.47682793598613565
#   (3, 19)	0.47346472219355856
#   (3, 42)	0.47346472219355856
#   (3, 14)	0.4530749097817592
#   (3, 20)	0.37273216359221073
#   (3, 15)	0.4554735711613497
#   (4, 17)	0.2753534747643768
#   (4, 37)	0.2753534747643768
#   (4, 22)	0.4620940203160738
#   (4, 18)	0.19670886455113246
#   (4, 40)	0.38365634005919574
#   :	:
#   (295, 1)	0.5660045034159257
#   (295, 35)	0.5822845077445765
#   (295, 26)	0.5331453140676202
#   (296, 18)	0.17360862958528003
#   (296, 11)	0.3392943399563413
#   (296, 34)	0.4019621408839084
# ...

# %%
#prediction in batches


# Define a function for batch predictions
def batch_predict(model, X_test, batch_size):
    predictions = []
    num_samples = X_test.shape[0]  # Use shape[0] to get the number of samples

    for i in range(0, num_samples, batch_size):
        # Get the batch
        batch = X_test[i:i + batch_size]

        # Make predictions on the current batch
        preds = model.predict(batch)
        predictions.extend(preds)

    return np.array(predictions)

# Get predictions on the test dataset in batches
batch_size = 20  # Define your batch size
predictions = batch_predict(mnb, X_test, batch_size)
print(predictions)
# Out:
# ['In' 'Out' 'In' 'Out' 'Out' 'Out' 'In' 'Out' 'Out' 'Out' 'In' 'Out' 'In'
#  'In' 'In' 'In' 'In' 'Out' 'Out' 'In' 'Out' 'Out' 'Out' 'In' 'In' 'In'
#  'Out' 'Out' 'Out' 'Out' 'In' 'In' 'Out' 'Out' 'In' 'Out' 'Out' 'In' 'Out'
#  'In' 'In' 'In' 'In' 'In' 'Out' 'In' 'Out' 'In' 'In' 'Out' 'Out' 'Out'
#  'Out' 'Out' 'Out' 'Out' 'Out' 'Out' 'Out' 'In' 'Out' 'In' 'Out' 'In'
#  'Out' 'Out' 'In' 'Out' 'Out' 'Out' 'Out' 'In' 'In' 'In' 'Out' 'Out' 'Out'
#  'Out' 'Out' 'In' 'Out' 'In' 'Out' 'Out' 'In' 'Out' 'In' 'Out' 'Out' 'In'
#  'Out' 'In' 'Out' 'In' 'In' 'Out' 'In' 'Out' 'In' 'Out' 'In' 'Out' 'In'
#  'In' 'Out' 'In' 'In' 'Out' 'In' 'In' 'Out' 'In' 'Out' 'In' 'Out' 'Out'
#  'Out' 'Out' 'In' 'In' 'Out' 'Out' 'In' 'Out' 'Out' 'In' 'Out' 'In' 'In'
#  'Out' 'Out' 'Out' 'In' 'Out' 'Out' 'In' 'In' 'In' 'Out' 'In' 'Out' 'In'
#  'In' 'Out' 'In' 'In' 'Out' 'In' 'In' 'Out' 'Out' 'Out' 'Out' 'Out' 'Out'
#  'Out' 'Out' 'Out' 'Out' 'In' 'Out' 'Out' 'In' 'In' 'Out' 'Out' 'Out' 'In'
# ...

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 0.47
# Confusion Matrix:
# [[69 88]
#  [71 72]]
# Classification Report:
#               precision    recall  f1-score   support
#
#           In       0.49      0.44      0.46       157
#          Out       0.45      0.50      0.48       143
#
#     accuracy                           0.47       300
#    macro avg       0.47      0.47      0.47       300
# weighted avg       0.47      0.47      0.47       300

# %%
from sklearn.tree import DecisionTreeClassifier

for i in range(3,20):
  model = DecisionTreeClassifier(max_depth=i)
  model.fit(X_train,y_train)
  print(i, model.score(X_test,y_test))
# Out:
# 3 0.48333333333333334
# 4 0.48
# 5 0.48333333333333334
# 6 0.48333333333333334
# 7 0.49666666666666665
# 8 0.49333333333333335
# 9 0.49666666666666665
# 10 0.4866666666666667
# 11 0.5166666666666667
# 12 0.5033333333333333
# 13 0.51
# 14 0.5166666666666667
# 15 0.5166666666666667
# 16 0.49
# 17 0.5033333333333333
# 18 0.5166666666666667
# 19 0.5066666666666667

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=50, max_features=10, max_depth=5)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.5033333333333333

# %%
model.score(X_test,y_test)
# Out:
# 0.5033333333333333

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(X_test,y_test)
# Out:
# 0.5333333333333333

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split


# Preprocess the text data
X = df['Text'].values
y = df['Scope'].values

# Tokenize the text
tokenizer = Tokenizer(num_words=1000, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
sequences = tokenizer.texts_to_sequences(X)

# Pad the sequences to ensure uniform length
padded_sequences = pad_sequences(sequences, maxlen=20)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, y, test_size=0.2, random_state=42)

# Build a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(1000, 16, input_length=20),  # Embedding layer for text
    tf.keras.layers.GlobalAveragePooling1D(),               # Pooling layer
    tf.keras.layers.Dense(24, activation='relu'),           # Hidden dense layer
    tf.keras.layers.Dense(1, activation='sigmoid')          # Output layer (binary classification)
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc}")

# Predict on a new message
new_message = ["You have won a lottery, claim your prize now!"]
sequence = tokenizer.texts_to_sequences(new_message)
padded_sequence = pad_sequences(sequence, maxlen=20)
prediction = model.predict(padded_sequence)

if prediction > 0.5:
    print("In")
else:
    print("Out")
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.4604 - loss: 0.6937 - val_accuracy: 0.4650 - val_loss: 0.6932
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4915 - loss: 0.6932 - val_accuracy: 0.4950 - val_loss: 0.6932
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5279 - loss: 0.6930 - val_accuracy: 0.4850 - val_loss: 0.6936
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5235 - loss: 0.6925 - val_accuracy: 0.4850 - val_loss: 0.6936
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5129 - loss: 0.6926 - val_accuracy: 0.4750 - val_loss: 0.6935
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5324 - loss: 0.6924 - val_accuracy: 0.4700 - val_loss: 0.6937
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5137 - loss: 0.6923 - val_accuracy: 0.5050 - val_loss: 0.6936
# Epoch 8/10
# ...
