# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# %pip install pandas openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !git clone https://github.com/Anand0583/text_classification_de.git
# Out:
# Cloning into 'text_classification_de'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 121.91 KiB | 1.34 MiB/s, done.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_excel("/content/text_classification_de/Enhanced_Synthetic_Data_10000.xlsx")

# %%
df.head(20)
# Out:
#                                                  Text Scope
# 0   Best practices for database management for aut...    In
# 1   Guide to using database management for AI deve...    In
# 2                      What is SQL queries in finance   Out
# 3    Best practices for web development for reporting    In
# 4   Introduction to database management for data p...   Out
# 5           Setting up Python programming in business    In
# 6    Steps to optimize Python programming in practice    In
# 7                 Mastering SQL queries for reporting    In
# 8        Best practices for cloud services in finance    In
# 9       Best practices for Excel functions in finance    In
# 10            Tutorial on web development in business    In
# 11  Steps to optimize Machine learning models in p...    In
# 12         The history of Data analysis for reporting   Out
# 13              Background on SQL queries in business   Out
# 14              Setting up web development in finance    In
# 15  Overview of Python programming for AI development   Out
# 16        What is web development for data processing   Out
# 17           Steps to optimize SQL queries in finance    In
# 18         Tutorial on Python programming in practice    In
# 19                 What is cloud services in practice   Out

# %%
# %cd /content/text_classification_de
# Out:
# /content/text_classification_de

# %%
from text_preprocessing import remove_tags,preprocess_text,label_encoder_fit_and_transform, generate_train_test_val_data,preprocess_function,get_encoded_train_validation_tf_data
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
#use preprocess.py
#df['text].apply(preprcoess)

X = df['Text']
y = df['Scope']

# %%
df.isna().sum()
# Out:
# Text     0
# Scope    0
# dtype: int64

# %%
# Assuming 'text_column' is the name of the column with the text data
df['cleaned_text'] = df['Text'].apply(lambda x: remove_tags(x))
df['cleaned_text'] = df['cleaned_text'].apply(lambda x: preprocess_text(x))

print(df['cleaned_text'].head(10))  # Check preprocessed text
# Out:
# 0    Best practices for database management for aut...
# 1    Guide to using database management for AI deve...
# 2                       What is SQL queries in finance
# 3     Best practices for web development for reporting
# 4    Introduction to database management for data p...
# 5            Setting up Python programming in business
# 6     Steps to optimize Python programming in practice
# 7                  Mastering SQL queries for reporting
# 8         Best practices for cloud services in finance
# 9        Best practices for Excel functions in finance
# Name: cleaned_text, dtype: object

# %%
df = label_encoder_fit_and_transform(df,'Scope')
df.head(5)
# Out:
# Index(['Scope'], dtype='object')
#                                                 Text  \
# 0  Best practices for database management for aut...
# 1  Guide to using database management for AI deve...
# 2                     What is SQL queries in finance
# 3   Best practices for web development for reporting
# 4  Introduction to database management for data p...
#
#                                         cleaned_text  Scope
# 0  Best practices for database management for aut...      0
# 1  Guide to using database management for AI deve...      0
# 2                     What is SQL queries in finance      1
# 3   Best practices for web development for reporting      0
# 4  Introduction to database management for data p...      1

# %%
generate_train_test_val_data("/content/text_classification_de/Enhanced_Synthetic_Data_1000.xlsx")
# Out:
# (1000, 2)
# The column headers :
# ['Text', 'Scope']
# (1000, 2)
# The column headers :
# ['Text', 'Scope']
# Index(['Scope'], dtype='object')
# 2
# (800, 2)
# (100, 2)
# (100, 2)

# %%
vectorizer = TfidfVectorizer()
X_vectors = vectorizer.fit_transform(X)
print(X_vectors)
# Out:
#   (0, 5)	0.4672837294643196
#   (0, 35)	0.4672837294643196
#   (0, 16)	0.3575074188735528
#   (0, 10)	0.38099880918720436
#   (0, 27)	0.38099880918720436
#   (0, 2)	0.38099880918720436
#   (1, 16)	0.16967316546507086
#   (1, 10)	0.3616443776014614
#   (1, 27)	0.3616443776014614
#   (1, 18)	0.44971453084300145
#   (1, 46)	0.2836700411234015
#   (1, 50)	0.44971453084300145
#   (1, 0)	0.3700800082776662
#   (1, 11)	0.2961815017166576
#   (2, 52)	0.48044771497286193
#   (2, 23)	0.48044771497286193
#   (2, 43)	0.3969399390148751
#   (2, 39)	0.3969399390148751
#   (2, 21)	0.2544310141174033
#   (2, 15)	0.3980982479735818
#   (3, 5)	0.4756834639134748
#   (3, 35)	0.4756834639134748
#   (3, 16)	0.3639338514514285
#   (3, 11)	0.31764149137242614
#   (3, 51)	0.3989117002751246
#   :	:
#   (9996, 28)	0.5063365049716214
#   (9996, 25)	0.4110853426065412
#   (9996, 24)	0.4110853426065412
#   (9996, 29)	0.4110853426065412
#   (9997, 16)	0.18521194073011446
#   (9997, 40)	0.40069019242486786
#   (9997, 38)	0.3955654990521085
#   (9997, 37)	0.3955654990521085
#   (9997, 45)	0.3991314357069554
#   (9997, 19)	0.4875913928803784
#   (9997, 30)	0.30846151987613707
#   (9998, 21)	0.2525665299079166
#   (9998, 34)	0.39413524159365293
#   (9998, 13)	0.39392712711707983
#   (9998, 17)	0.39392712711707983
#   (9998, 45)	0.39023825347023583
#   (9998, 19)	0.4767272044802323
#   (9998, 30)	0.30158858463761057
#   (9999, 21)	0.25363256941584705
#   (9999, 15)	0.39684895280453186
#   (9999, 7)	0.3896734300690515
#   (9999, 41)	0.3896734300690515
#   (9999, 45)	0.391885381440267
#   (9999, 19)	0.478739387308521
#   (9999, 30)	0.30286153773429264

# %%
X_train, X_test, y_train, y_test = train_test_split(X_vectors, y, test_size=0.3, random_state=42)

# %%
# Create a Multinomial Naive Bayes classifier
mnb = MultinomialNB()

# Train the model
mnb.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
import joblib
joblib.dump(mnb, 'mnb.pkl')
# Out:
# ['mnb.pkl']

# %%
# Make predictions on the test set
y_pred = mnb.predict(X_test)
print(X_test)
print(y_pred)
# Out:
#   (0, 16)	0.21306930087191336
#   (0, 13)	0.4635044223787445
#   (0, 17)	0.4635044223787445
#   (0, 4)	0.4585710189578681
#   (0, 48)	0.5609290458414412
#   (1, 16)	0.18511919403728375
#   (1, 2)	0.3945663153404155
#   (1, 25)	0.39903485193891247
#   (1, 24)	0.39903485193891247
#   (1, 29)	0.39903485193891247
#   (1, 30)	0.3083070547497458
#   (1, 33)	0.48714333373606
#   (2, 16)	0.20192461651556187
#   (2, 7)	0.43269108745619517
#   (2, 41)	0.43269108745619517
#   (2, 30)	0.3362956722188753
#   (2, 4)	0.4345852582671332
#   (2, 8)	0.5318121558038492
#   (3, 16)	0.17894005172762656
#   (3, 31)	0.3862157460270616
#   (3, 25)	0.3857153625717163
#   (3, 24)	0.3857153625717163
#   (3, 29)	0.3857153625717163
#   (3, 3)	0.4734694545606073
#   (3, 4)	0.3851175252245266
#   :	:
#   (2995, 3)	0.4734694545606073
#   (2995, 4)	0.3851175252245266
#   (2996, 16)	0.18522486844326444
#   (2996, 2)	0.394791551633229
#   (2996, 42)	0.4973741940925301
#   (2996, 49)	0.4973741940925301
#   (2996, 7)	0.39690628677989925
#   (2996, 41)	0.39690628677989925
#   (2997, 16)	0.17714582999481998
#   (2997, 52)	0.46655186161488627
#   (2997, 23)	0.46655186161488627
#   (2997, 9)	0.30288883032040675
#   (2997, 36)	0.38017820013667547
#   (2997, 13)	0.3853576055891387
#   (2997, 17)	0.3853576055891387
#   (2998, 21)	0.30272080799380247
#   (2998, 15)	0.47365539812638996
#   (2998, 9)	0.37110917238386404
#   (2998, 1)	0.4688245383739231
#   (2998, 48)	0.571394969022612
#   (2999, 43)	0.45150031104305555
#   (2999, 39)	0.45150031104305555
#   (2999, 21)	0.2894031835095907
#   (2999, 15)	0.45281783242031465
#   (2999, 28)	0.5509053877688349
# [0 1 1 ... 1 0 0]

# %%
#prediction in batches


# Define a function for batch predictions
def batch_predict(model, X_test, batch_size):
    predictions = []
    num_samples = X_test.shape[0]  # Use shape[0] to get the number of samples

    for i in range(0, num_samples, batch_size):
        # Get the batch
        batch = X_test[i:i + batch_size]

        # Make predictions on the current batch
        preds = model.predict(batch)
        predictions.extend(preds)

    return np.array(predictions)

# Get predictions on the test dataset in batches
batch_size = 10  # Define your batch size
predictions = batch_predict(mnb, X_test, batch_size)
print(predictions)
# Out:
# [0 1 1 ... 1 0 0]

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Confusion Matrix:')
print(conf_matrix)
print('Classification Report:')
print(class_report)
# Out:
# Accuracy: 1.00
# Confusion Matrix:
# [[1501    0]
#  [   0 1499]]
# Classification Report:
#               precision    recall  f1-score   support
#
#           In       1.00      1.00      1.00      1501
#          Out       1.00      1.00      1.00      1499
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
from sklearn.tree import DecisionTreeClassifier

for i in range(3,20):
  model = DecisionTreeClassifier(max_depth=i)
  model.fit(X_train,y_train)
  print(i, model.score(X_test,y_test))
  if i == 19:
    joblib.dump(model, 'decision_model.pkl')
# Out:
# 3 0.778
# 4 0.8045
# 5 0.87
# 6 0.9565
# 7 0.961
# 8 0.993
# 9 0.997
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=50, max_features=10, max_depth=5)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 1.0

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split


# Preprocess the text data
X = df['Text'].values
y = df['Scope'].values

# Tokenize the text
tokenizer = Tokenizer(num_words=1000, oov_token='<OOV>')
tokenizer.fit_on_texts(X)
sequences = tokenizer.texts_to_sequences(X)

# Pad the sequences to ensure uniform length
padded_sequences = pad_sequences(sequences, maxlen=20)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, y, test_size=0.2, random_state=42)

# Build a simple neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(1000, 16, input_length=20),  # Embedding layer for text
    tf.keras.layers.GlobalAveragePooling1D(),               # Pooling layer
    tf.keras.layers.Dense(24, activation='relu'),           # Hidden dense layer
    tf.keras.layers.Dense(1, activation='sigmoid')          # Output layer (binary classification)
])

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc}")
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6970 - loss: 0.6188 - val_accuracy: 1.0000 - val_loss: 0.1697
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.1068 - val_accuracy: 1.0000 - val_loss: 0.0223
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0169 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 8.1828e-04
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 7.6218e-04 - val_accuracy: 1.0000 - val_loss: 5.8513e-04
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 1.0000 - loss: 5.5210e-04 - val_accuracy: 1.0000 - val_loss: 4.3542e-04
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.1259e-04 - val_accuracy: 1.0000 - val_loss: 3.3132e-04
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3409e-04
# Test Accuracy: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# Out

# %%
# Predict on a new message
new_message = ["Organize a New Workbook in Google Sheets"]
sequence = tokenizer.texts_to_sequences(new_message)
padded_sequence = pad_sequences(sequence, maxlen=20)
prediction = model.predict(padded_sequence)

if prediction > 0.5:
    print("In")
else:
    print("Out")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Out
